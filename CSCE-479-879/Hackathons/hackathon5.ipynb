# %% [markdown]
# # CSCE 479/879 Hackathon: Batch Normalization and Residual Architectures
#
# Written by Eleanor Quint
#
# Modified by Mrinal Rawool and Stephen Scott
#
# Topics:
# - Batch Normalization
# - Residual architectures
#
# This is all setup in a IPython notebook so you can run any code you want to experiment with. Feel free to edit any cell, or add some to run your own code.

# %%
# We'll start with our library imports...
from __future__ import print_function

import numpy as np                 # to use numpy arrays
import tensorflow as tf            # to specify and run computation graphs
import tensorflow_datasets as tfds # to load training data
import matplotlib.pyplot as plt    # to visualize data and draw plots
from tqdm import tqdm              # to track progress of loops

DATA_DIR = './tensorflow-datasets/'
np.random.seed(42)
import time

# %% [markdown]
# #### Batch Normalization
#
# During training, the `tf.keras.layers.BatchNormalization` layer normalizes its output using the mean and standard deviation of the current batch of inputs.
#
#
# ![image.png](data:image/png;base64,...)
#
#
# That is to say, for each channel being normalized, the layer returns $(batch - mean(batch)) / (var(batch) + \epsilon) * \gamma + \beta$, where:
#
# - $\epsilon$ is small constant
# - $\gamma$ is a learned scaling factor (initialized as 1), which can be disabled by passing scale=False to the constructor
# - $\beta$ is a learned offset factor (initialized as 0), which can be disabled by passing center=False to the constructor

# %%
# Let's create some shifted data (i.e with a non zero mean and SD)
shifted_data = tf.random.normal(shape=[64], mean=-1.8, stddev=4.3)

shifted_data_2_32 = tf.reshape(shifted_data, shape=(2, 32))
# Out:
# 2025-10-29 10:22:35.298811: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :
# 2025-10-29 10:22:35.298844: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2025-10-29 10:22:35.298861: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (c1216.swan.hcc.unl.edu): /proc/driver/nvidia/version does not exist
# 2025-10-29 10:22:35.299191: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# print("Shifted/scaled statistics:", tf.math.reduce_mean(shifted_data).numpy(), 
#       tf.math.reduce_std(shifted_data).numpy()) 

# print("Shifted/scaled statistics:", tf.math.reduce_mean(shifted_data_2_32).numpy(), 
#       tf.math.reduce_std(shifted_data_2_32).numpy())

print("Shifted/scaled statistics calculated for each batch: \nMean=> {} \nVar=> {}".format(tf.math.reduce_mean(shifted_data_2_32, axis=1).numpy(), 
      tf.math.reduce_std(shifted_data_2_32, axis=1).numpy()))
# Out:
# Shifted/scaled statistics calculated for each batch:
# Mean=> [-1.0061414 -0.843835 ]
# Var=> [4.794993  4.0781794]

# %%
x = np.arange(32)
y = shifted_data_2_32[0]

plt.subplot(1,2,1) # r, c, idx
plt.title("Shifted data: First Batch")
plt.bar(x,y)

x = np.arange(32)
y = shifted_data_2_32[1]

plt.subplot(1,2,2) # r, c, idx
plt.title("Shifted data: Second Batch")
plt.bar(x,y)
# Out:
# <BarContainer object of 32 artists>

# %%
# Run this if you want to init this layer only once.
# if 'batch_norm' not in locals():
#     batch_norm = tf.keras.layers.BatchNormalization()

batch_norm = tf.keras.layers.BatchNormalization()

normd_data = batch_norm(shifted_data_2_32, training=True)
print("Training batch normd statistics:",
      tf.math.reduce_mean(normd_data, axis=1).numpy(), tf.math.reduce_std(normd_data, axis=1).numpy())

x = np.arange(32)
y = normd_data[0]

plt.subplot(1,2,1) # r, c, idx
plt.title("Normalized data: First Batch")
plt.bar(x,y)


x = np.arange(32)
y = normd_data[1]

plt.subplot(1,2,2) # r, c, idx
plt.title("Normalized data: Second Batch")
plt.bar(x,y)
# Out:
# Training batch normd statistics: [ 0.04713473 -0.04713485] [0.9691736 0.9691736]
# <BarContainer object of 32 artists>

# %%
# This is what the BN layer uses for normalization during inference time
print("Moving mean:", tf.reduce_mean(batch_norm.moving_mean).numpy(),
      "Moving variance:", tf.reduce_mean(batch_norm.moving_variance).numpy())
# compare with input data mean:-0.80648726 SD: 4.554053
# Out:
# Moving mean: -0.009249883 Moving variance: 1.0767838

# %%
# The first time this cell is run, the statistics will be almost identical to the original data
# The 100th time this cell is run, it should be close to the statistics of the normalized data (i.e., 0 mean and 0 std)
inference_normd_data = batch_norm(shifted_data_2_32, training=False)
print("Batch-wise Inference batch normd statistics:",
      tf.math.reduce_mean(inference_normd_data, axis=1).numpy(), 
      tf.math.reduce_std(inference_normd_data, axis=1).numpy())

# this will consider both batches together. We will be using this method for the demo below
print("Inference batch normd statistics:",
      tf.math.reduce_mean(inference_normd_data).numpy(), 
      tf.math.reduce_std(inference_normd_data).numpy())
# Out:
# Batch-wise Inference batch normd statistics: [-0.9510646  -0.84543085] [4.4039025 3.9090462]
# Inference batch normd statistics: -0.89824766 4.164167

# %% [markdown]
# **Why is the output mean and SD non zero?**
#
# During inference (when calling the layer/model with the argument training=False (which is the default)), the layer normalizes its output using a moving average of the mean and standard deviation of the batches it has seen during training. That is to say, it returns
#
# (batch - self.moving\_mean) / (self.moving\_var + $\epsilon) * \gamma + \beta$
#
# self.moving_mean and self.moving_var are non-trainable variables that are updated each time the layer in called in training mode, as such:
#
# ```
# moving_mean = moving_mean * momentum + mean(batch) * (1 - momentum)
# moving_var = moving_var * momentum + var(batch) * (1 - momentum)
# ```
#
# As such, the layer will only normalize its inputs during inference after having been trained on data that has similar statistics as the inference data.
#
# Let's demonstrate how this works:

# %% [markdown]
# ### Demo

# %%
shifted_data = tf.reshape(tf.random.normal(shape=[64], mean=-1.8, stddev=4.3, seed = 11), 
                           shape=(2, 32))

print("Shifted/scaled statistics:",
      tf.math.reduce_mean(shifted_data).numpy(), tf.math.reduce_std(shifted_data).numpy())

batch_norm_1 = tf.keras.layers.BatchNormalization()

bnl_moving_mean = []
bnl_moving_var = []

# try for 10 iters and examine the plots below. Then try for higher # iters
for i in range(1000):
    normd_data = batch_norm_1(shifted_data, training=True)
    bnl_moving_mean.append(tf.reduce_mean(batch_norm_1.moving_mean).numpy())
    bnl_moving_var.append(tf.reduce_mean(batch_norm_1.moving_variance).numpy())

# after 1000 iterations:
inference_normd_data = batch_norm_1(shifted_data, training=False)
print("Inference batch normd statistics:",
      tf.math.reduce_mean(inference_normd_data).numpy(), tf.math.reduce_std(inference_normd_data).numpy())
# Out:
# Shifted/scaled statistics: -1.8100402 4.374397
# Inference batch normd statistics: -5.6578778e-05 0.99546415

# %%
x = np.arange(32)
y = shifted_data[0]
plt.subplot(2,2,1) # r, c, idx
plt.title("Shifted data: First Batch")
plt.bar(x,y)

x = np.arange(32)
y = inference_normd_data[0]
plt.subplot(2,2,2) # r, c, idx
plt.title("Normalized data: First Batch")
plt.bar(x,y)

x = np.arange(32)
y = shifted_data[1]
plt.subplot(2,2,3) # r, c, idx
plt.title("Shifted data: Second Batch")
plt.bar(x,y)

x = np.arange(32)
y = inference_normd_data[1]
plt.subplot(2,2,4) # r, c, idx
plt.title("Normalized data: Second Batch")
plt.bar(x,y)

plt.tight_layout()

# %%
plt.subplot(1,2,1)
plt.title('BN layer moving mean v/s iterations', fontsize=10)
plt.plot(np.arange(1000), bnl_moving_mean) # 1000 = iters

plt.subplot(1,2,2)
plt.title('BN layer moving var v/s iterations', fontsize=10)
plt.plot(np.arange(1000), bnl_moving_var) # 1000 = iters

plt.tight_layout()

# %% [markdown]
# Batch normalization is usually pretty unnecessary in smaller networks. Its main purpose is to make training deeper networks faster and easier. Once batch normalization was introduced, much work went into designing deeper and more effective architectures. Two examples from ResNet are below. These are called residual architectures, so called because they compute a residual value $f(x)$ to add to the input value of the representation $x$.
#
# <div>
# <img src="attachment:92b1bfa0-45c9-43b2-8dce-a4ab0171ac98.png" width="500"/>
# </div>
#
# The first example is a standard "ResNet Block", which is still in wide use.

# %% [markdown]
# # Residual Block

# %%
# class ResBlock(tf.Module):
class ResBlock(tf.keras.layers.Layer):

    def __init__(self, filter_num, stride=1):
        super().__init__()
        self.stride = stride

        # Both self.conv1 and self.down_conv layers downsample the input when stride != 1
        self.bn1 = tf.keras.layers.BatchNormalization()
        self.conv1 = tf.keras.layers.Conv2D(filters=filter_num,
                                            kernel_size=(3, 3),
                                            strides=stride,
                                            padding="same")
        self.bn2 = tf.keras.layers.BatchNormalization()
        self.conv2 = tf.keras.layers.Conv2D(filters=filter_num,
                                            kernel_size=(3, 3),
                                            padding="same")

        if self.stride != 1:
            self.down_conv = tf.keras.layers.Conv2D(filters=filter_num,
                                                    kernel_size=(1, 1),
                                                    strides=stride,
                                                    padding="same")
            self.down_bn = tf.keras.layers.BatchNormalization()

    # def __call__(self, x, is_training=False):
    def call(self, x, training=False):
        identity = x

        # when teh stride > 1, the l, h of the image changes. We need to match the residual stream dims to the 
        # changed dims - hence
        if self.stride != 1:
            identity = self.down_conv(identity)
            identity = self.down_bn(identity, training=training)

        x = self.bn1(x, training=training)
        x = tf.nn.relu(x)
        x = self.conv1(x)


        x = self.bn2(x, training=training)
        x = tf.nn.relu(x)
        x = self.conv2(x)

        out = x + identity # self.bn2((x + identity), training=training)

        return out

# %% [markdown]
# ### Demo using mnist

# %%
# Let's use the code from Hack2 to load MNIST
ds = tfds.load('mnist', shuffle_files=True, data_dir = DATA_DIR) # this loads a dict with the datasets

# We can create an iterator from each dataset
# This one iterates through the train data, shuffling and minibatching by 32
train_ds = ds['train'].shuffle(1024).batch(32)

# %%
train_ds
# Out:
# <BatchDataset shapes: {image: (None, 28, 28, 1), label: (None,)}, types: {image: tf.uint8, label: tf.int64}>

# %%
for batch in train_ds:
    images = tf.cast(batch["image"], tf.float32)/255.0
    labels = batch["label"]
    print(images.shape)
    break
# Out:
# (32, 28, 28, 1)
# 2025-10-29 10:22:37.284543: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2025-10-29 10:22:37.356691: W tensorflow/core/kernels/data/cache_dataset_ops.cc:768] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.

# %%
idx = 1
img = images[idx-1:idx]
label = labels[idx-1:idx]

print(img.shape)
plt.imshow(img[0], cmap="gray")
plt.show()
print(label)
# Out:
# (1, 28, 28, 1)
# tf.Tensor([6], shape=(1,), dtype=int64)

# %% [markdown]
# ### Residual block as de-noising block

# %%
def create_model(seed, resblock_nfilters=4):
    
    np.random.seed(42)
    my_res_block = ResBlock(filter_num=resblock_nfilters, stride=1)
    final_conv = tf.keras.layers.Conv2D(
        filters=1,
        kernel_size=(1, 1),
        strides=1,
        padding="same",
        name='final_conv'
    )
    
    model = tf.keras.Sequential([my_res_block, final_conv])
    return model

# %%
def create_model_clf(seed, resblock_nfilters=4):

    np.random.seed(42)
    my_res_block = ResBlock(filter_num=resblock_nfilters, stride=1)
    final_conv = tf.keras.layers.Conv2D(
        filters=1,
        kernel_size=(1, 1),
        strides=1,
        padding="same",
        name='final_conv'
    )
    flatten = tf.keras.layers.Flatten()
    # Dense layers have 10 units because we have 10 classes
    output = tf.keras.layers.Dense(10)
    
    model = tf.keras.Sequential([my_res_block, final_conv, flatten, output])
    return model

# %% [markdown]
# ### Create models

# %%
model = create_model(42, resblock_nfilters=8)
orig_model = create_model(42, resblock_nfilters=8)

# %%
model_clf = create_model_clf(42, resblock_nfilters=8)
orig_model_clf = create_model_clf(42, resblock_nfilters=8)

# %%
def normalize(img):
    min_val = tf.reduce_min(img)
    max_val = tf.reduce_max(img)
    return (img - min_val) / (max_val - min_val + 1e-8)

# %%
def add_salt_pepper_noise(x, prob=0.1):
    # unique time-based seed per call
    t = int(time.time() * 1e6) % (2**31 - 1)
    seed = [t, t // 2]  # two ints required
    rnd = tf.random.stateless_uniform(x.shape, seed=seed)
    add_salt = tf.where(rnd < prob/2, 0.0, x)
    add_salt_pepper = tf.where(rnd > 1 - prob/2, 1.0, add_salt)
    return add_salt_pepper

# %% [markdown]
# ### Train the model

# %%
def reconstruction_loss(x, x_hat):
    reconstruction_loss = tf.reduce_mean(tf.square(x_hat - x)) # Mean Square Error
    total_loss = reconstruction_loss
    return total_loss

# %%
max_steps = 1000
step = 0
optimizer = tf.keras.optimizers.Adam()
losses = []

for batch in tqdm(train_ds):
    with tf.GradientTape() as tape:
        x = tf.cast(batch['image'], tf.float32)/255
        noisy_input = x + add_salt_pepper_noise(x, prob=0.1)
        output = model(noisy_input, training=True)
        loss = reconstruction_loss(x, output)
        losses.append(loss)
    gradient = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradient, model.trainable_variables))
    step += 1
    if step > max_steps:
        break
# Out:
# ...
#  53%|█████▎    | 1000/1875 [00:27<00:24, 36.44it/s]

# %%
plt.plot(losses)

# %% [markdown]
# ### View/ compare output for trained and untrained denoiser

# %%
idx = 1
img = images[idx-1:idx]
label = labels[idx-1:idx]

noisy_img = img + add_salt_pepper_noise(img, prob=0.1)

trained_model_output = model(noisy_img, training=False)
trained_model_output = normalize(trained_model_output)

untrained_model_output = orig_model(noisy_img, training=False)
untrained_model_output = normalize(untrained_model_output)

print(f"recon loss: trained model {reconstruction_loss(img, trained_model_output).numpy()}")
print(f"recon loss: untrained model {reconstruction_loss(img, untrained_model_output).numpy()}")

print(f"L->R 1. Orig image 2. Noisy image",
      f"3. Trained model output 4. Untrained dmodel output"
     )
fig, axes = plt.subplots(1, 4, figsize=(9, 3))  # 1 row, 3 columns
imgs =  [img[0].numpy(), noisy_img[0].numpy(), trained_model_output[0], untrained_model_output[0]]

for ax, im in zip(axes, imgs):
    ax.imshow(im, cmap='gray')   # or omit cmap if RGB, cmap='gray'
    ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# recon loss: trained model 0.017700476571917534
# recon loss: untrained model 0.7135791182518005
# L->R 1. Orig image 2. Noisy image 3. Trained model output 4. Untrained dmodel output

# %%
all_ones = tf.ones(img.shape, dtype= tf.float32)
out_all_ones = model(all_ones, training=False)
out_all_ones = normalize(out_all_ones)

out_all_ones_orig = orig_model(all_ones, training=False)
out_all_ones_orig = normalize(out_all_ones_orig)

print(reconstruction_loss(all_ones, out_all_ones).numpy())
print(reconstruction_loss(all_ones, out_all_ones_orig).numpy())

print(f"L->R 1. Orig image 2. Output of untrained model with input=orig image",
      f"3. Output of trained model with input=orig image"
     )

fig, axes = plt.subplots(1, 3, figsize=(9, 3))  # 1 row, 3 columns
imgs =  [all_ones[0,:,:, :].numpy(), out_all_ones_orig[0,:,:, :], out_all_ones[0,:,:, :]]

for ax, im in zip(axes, imgs):
    ax.imshow(im, cmap='gray', vmin=0.0, vmax=1.0)   # or omit cmap if RGB
    ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 0.02859935
# 0.22488244
# L->R 1. Orig image 2. Output of untrained model with input=orig image 3. Output of trained model with input=orig image

# %%
checker = tf.tile([[0., 1.], [1., 0.]], [14, 14])
checker = tf.expand_dims(checker, axis = -1)
checker = tf.expand_dims(checker, axis = 0)
print(checker.shape)

out_checker = model(checker, training=False)
out_checker = normalize(out_checker)

out_checker_orig = orig_model(checker, training=False)
out_checker_orig = normalize(out_checker_orig)

print(reconstruction_loss(checker, out_checker).numpy())
print(reconstruction_loss(checker, out_checker_orig).numpy())

print(f"L->R 1. Orig image 2. Output of trained model with input=orig image",
      f"3. Output of untrained model with input=orig image"
     )
fig, axes = plt.subplots(1, 3, figsize=(9, 3))  # 1 row, 3 columns
imgs =  [checker[0,:,:, :].numpy(), out_checker[0,:,:, :], out_checker_orig[0,:,:, :]]

for ax, im in zip(axes, imgs):
    ax.imshow(im, cmap='gray', vmin=0.0, vmax=1.0)   # or omit cmap if RGB
    ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# (1, 28, 28, 1)
# 0.08199074
# 0.80799234
# L->R 1. Orig image 2. Output of trained model with input=orig image 3. Output of untrained model with input=orig image

# %% [markdown]
# ### Train clf - trained w/o noise for this demo

# %%
# Optimizer, loss, metric
optimizer = tf.keras.optimizers.Adam(1e-3)
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

EPOCHS = 1
max_batches = 100
for epoch in range(EPOCHS):

    epoch_loss = 0.0
    steps = 0

    for batch in train_ds:
        x = tf.cast(batch['image'], tf.float32) / 255.0  # scale to [0,1]
        y = tf.cast(batch['label'], tf.int32)            # sparse labels
        with tf.GradientTape() as tape:
            logits = model_clf(x, training=True)
            loss = loss_fn(y, logits)
        grads = tape.gradient(loss, model_clf.trainable_variables)
        optimizer.apply_gradients(zip(grads, model_clf.trainable_variables))
        epoch_loss += loss
        steps += 1
        if steps>max_batches:
            break

    print(f"Epoch {epoch+1}: loss={(epoch_loss/steps).numpy():.4f} ")
# Out:
# Epoch 1: loss=1.0639
# 2025-10-29 10:23:08.221708: W tensorflow/core/kernels/data/cache_dataset_ops.cc:768] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.

# %%
idx = 2
img = images[idx-1:idx]
label = labels[idx-1:idx]

# img = tf.cast(img, tf.float32)/255.0
out_logits = model_clf(img, training=False)
print("True ", label.numpy())
print("Predicted ", tf.math.argmax(out_logits, axis=-1).numpy())

plt.imshow(img[0].numpy(), cmap="gray")
plt.show()
# Out:
# True  [3]
# Predicted  [3]

# %% [markdown]
# ### View feature maps - denoising

# %%
def plot_feature_maps(feature_maps, title="Feature maps"):

    fmap = feature_maps[0].numpy() # Tensor of shape (1, H, W, C)
    num_filters = fmap.shape[-1]
    rows, cols = 2, 4
    fig, axes = plt.subplots(rows, cols, figsize=(12, 6))
    fig.suptitle(title, fontsize=14)

    for i, ax in enumerate(axes.flat):
        if i < num_filters:
            img = fmap[..., i]
            # normalize each feature map for visibility
            img = normalize(img)
            ax.imshow(img, cmap='gray', vmin=0, vmax=1)
            ax.set_title(f"Filter {i+1}", fontsize=10)
        ax.axis("off")

    plt.tight_layout()
    plt.show()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# res_block (ResBlock)         (None, 28, 28, 8)         700
# _________________________________________________________________
# final_conv (Conv2D)          (None, 28, 28, 1)         9
# ...
# Total params: 709
# Trainable params: 691
# Non-trainable params: 18
# _________________________________________________________________

# %%
# what do filters learn?
idx = 1
img = images[idx-1:idx]
label = labels[idx-1:idx]

noisy_img = img + add_salt_pepper_noise(img, prob=0.1)

res_block = model.layers[0]   # This is the ResNet block
conv1_out = res_block.conv1(noisy_img)
conv2_out = res_block.conv2(conv1_out)

# %%
conv1_out.shape
# Out:
# TensorShape([1, 28, 28, 8])

# %%
conv2_out.shape
# Out:
# TensorShape([1, 28, 28, 8])

# %%
plot_feature_maps(conv1_out, title="Conv1 feature maps")

# %% [markdown]
# ### View feature maps - clf

# %%
idx = 2
img = images[idx-1:idx]
label = labels[idx-1:idx]

# img = tf.cast(img, tf.float32)/255.0
out_logits = model_clf(img, training=False)
print("True ", label.numpy())
print("Predicted ", tf.math.argmax(out_logits, axis=-1).numpy())
# Out:
# True  [3]
# Predicted  [3]

# %%
# idea - what do filters learn?
res_block = model_clf.layers[0]   # This is the ResNet block
conv1_out = res_block.conv1(img)
conv2_out = res_block.conv2(conv1_out)

# %%
plot_feature_maps(conv1_out, title="Conv1 feature maps")

# %% [markdown]
# ### Visualize filters

# %%
def visualize_kernels(kernels, title="Conv Kernels"):
    kH, kW, in_ch, out_ch = kernels.shape
    fig, axes = plt.subplots(2, 4, figsize=(8, 4))
    fig.suptitle(title)

    for i, ax in enumerate(axes.flat):
        if i < out_ch:
            kernel = kernels[:, :, 0, i]  # first input channel
            kernel = (kernel - kernel.min()) / (kernel.max() - kernel.min() + 1e-8)
            ax.imshow(kernel, cmap='gray')
            ax.set_title(f"Filter {i+1}")
        ax.axis('off')

    plt.tight_layout()
    plt.show()

# %%
conv_layer = model.layers[0].conv1   # your ResBlock’s first conv layer
kernels = conv_layer.kernel.numpy()  # shape: (kH, kW, in_channels, out_channels)
print(kernels.shape)

visualize_kernels(kernels, title="Conv1 kernels")
# Out:
# (3, 3, 1, 8)

# %%
conv_layer = model_clf.layers[0].conv1   # your ResBlock’s first conv layer
kernels = conv_layer.kernel.numpy()  # shape: (kH, kW, in_channels, out_channels)
print(kernels.shape)

visualize_kernels(kernels, title="Conv1 kernels")
# Out:
# (3, 3, 1, 8)

# %% [markdown]
# # Bottleneck Layer

# %%
EXPANSION_FACTOR = 4

class Bottleneck(tf.keras.layers.Layer):

    def __init__(self, filter_num, stride=1):
        super(Bottleneck, self).__init__()
        self.stride = stride
        assert filter_num % EXPANSION_FACTOR == 0, "filter_num should be a multiple of 4"

        self.conv1 = tf.keras.layers.Conv2D(filter_num // EXPANSION_FACTOR, kernel_size=1, padding='same')
        self.bn1 = tf.keras.layers.BatchNormalization()
        self.conv2 = tf.keras.layers.Conv2D(filter_num // EXPANSION_FACTOR, kernel_size=3, strides=stride, padding='same')
        self.bn2 = tf.keras.layers.BatchNormalization()
        self.conv3 = tf.keras.layers.Conv2D(filter_num, kernel_size=1, padding='same')
        self.bn3 = tf.keras.layers.BatchNormalization()

        if self.stride != 1:
            self.down_conv = tf.keras.layers.Conv2D(filters=filter_num,
                                                    kernel_size=(1, 1),
                                                    strides=stride,
                                                    padding="same")
            self.down_bn = tf.keras.layers.BatchNormalization()

    def __call__(self, x, training=False):
        identity = x
        if self.stride != 1:
            identity = self.down_conv(identity)
            identity = self.down_bn(identity, training=training)

        x = self.bn1(x, training=training)
        x = tf.nn.relu(x)
        x = self.conv1(x)

        x = self.bn2(x, training=training)
        x = tf.nn.relu(x)
        x = self.conv2(x)

        x = self.bn3(x, training=training)
        x = tf.nn.relu(x)
        x = self.conv3(x)

        return x + identity

# %%
def create_bn_model(seed):
    """Returns new, unshared instances of the layers."""
    # Each call creates a completely new layer object
    np.random.seed(42)
    my_bottle_block = Bottleneck(filter_num=8, stride=1)
    final_conv = tf.keras.layers.Conv2D(filters=1,
                                    kernel_size=(3, 3),
                                    strides=1,
                                    padding="same",
                                    name="final_conv")
    model = tf.keras.Sequential([my_bottle_block, final_conv])
    return model

# %% [markdown]
# ### Create model and train

# %%
model_bn = create_bn_model(42)
orig_model_bn = create_bn_model(42)

# %%
max_steps = 1000
step = 0
optimizer = tf.keras.optimizers.Adam()
losses = []

for batch in tqdm(train_ds):
    with tf.GradientTape() as tape:
        x = tf.cast(batch['image'], tf.float32)/255
        noisy_input = x + add_salt_pepper_noise(x)
        output = model_bn(noisy_input, training=True)
        loss = reconstruction_loss(x, output)
        losses.append(loss)
    gradient = tape.gradient(loss, model_bn.trainable_variables)
    optimizer.apply_gradients(zip(gradient, model_bn.trainable_variables))
    step += 1
    if step > max_steps:
        break
# Out:
# ...
#  53%|█████▎    | 1000/1875 [00:26<00:23, 37.77it/s]

# %%
plt.plot(losses)

# %% [markdown]
# ### Observe outputs

# %%
idx = 1
img = images[idx-1:idx]
label = labels[idx-1:idx]
noisy_img = img + add_salt_pepper_noise(img)

trained_model_output = model_bn(noisy_img, training=False)
trained_model_output = normalize(trained_model_output)

untrained_model_output = orig_model_bn(noisy_img, training=False)
untrained_model_output = normalize(untrained_model_output)

out_w_noise = model_bn(noisy_img, training=False)
out_w_noise = normalize(out_w_noise)

print(f"recon loss: trained model {reconstruction_loss(img, trained_model_output).numpy()}")
print(f"recon loss: untrained model {reconstruction_loss(img, untrained_model_output).numpy()}")

print(f"L->R 1. Orig image 2. Noisy image",
      f"3. Trained model output 4. Untrained model output"
     )
fig, axes = plt.subplots(1, 4, figsize=(9, 3))  # 1 row, 3 columns
imgs =  [img[0].numpy(), noisy_img[0].numpy(), trained_model_output[0], untrained_model_output[0]]

for ax, im in zip(axes, imgs):
    ax.imshow(im, cmap='gray')   # or omit cmap if RGB, cmap='gray'
    ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# recon loss: trained model 0.015285905450582504
# recon loss: untrained model 0.3195337653160095
# L->R 1. Orig image 2. Noisy image 3. Trained model output 4. Untrained model output

# %% [markdown]
# # Homework

# %% [markdown]
# For homework, compare the impact of noise levels on performance of a ResNet based network v/s a Bottleneck based network.
#
#
# 1. Choose any other dataset (eg. CIFAR10)
# 2. Compare resnet and bottleneck as denoiser OR as Classifiers. Make sure you tweak the Resnet layers a bit so that both blocks have same # convolutional layers so that the # parameters are comparable.
# 3. Train on noisy data with fixed noise level (e.g p=0.1 was used in the demo). You may use salt-and-pepper noise or any other noise like Gaussian noise.  (denoiser-model predicts cleaned image, clf-model predicts the label)
# 4. Test with different (unseen) noise levels p = {0.0, 0.2, 0.4, 0.6, 0.8} and compare the performance of resnet v/s bottleneck layer.
# 5. Plot loss (denoiser) or accuracy (for clf) v/s noise levels and explain your observations.
#
# What can you conclude about resnet v/s bottleneck blocks from your observations? You can use other visualization techniques such as feature maps or model outputs to support your conclusions.
#
# To submit:
# - `.py` file with the code
# - `.pdf` with your observations, plots, and figures.
